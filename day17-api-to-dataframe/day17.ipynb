# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     161.431
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     138.984
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     196.548
# 3  The true story of how businessman Oskar Schind...   1993-12-15      99.102
# 4  The defense and the prosecution have rested an...   1957-04-10      84.730
#
#    vote_average  vote_count
# 0         8.705       26162
# 1         8.700       19834
# 2         8.600       11971
# 3         8.568       15377
# 4         8.542        8247

# %%
# df = pd.DataFrame()
# df
# for i in range(1,429):
#     response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
#     temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
#     df = df.append(temp_df,ignore_index=True)

# %%
# df = []
# for i in range(1,429):
#     response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
#     temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
#     df = df(temp_df,ignore_index=True)

# %%
# Initialize an empty list to hold DataFrames
dfs = []

for i in range(1, 429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    dfs.append(temp_df)

# Concatenate the list of DataFrames into a single DataFrame
df = pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#           id                            title  \
# 0        278         The Shawshank Redemption
# 1        238                    The Godfather
# 2        240            The Godfather Part II
# 3        424                 Schindler's List
# 4        389                     12 Angry Men
# ...      ...                              ...
# 8555  306523            Ogni maledetto Natale
# 8556   10375                            D-Tox
# 8557  185341                [REC]⁴ Apocalypse
# 8558  146375  On the Other Side of the Tracks
# 8559   22787                         Whiteout
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# 8555  Massimo Marinelli Lops and Giulia Colardo meet...   2014-11-27
# 8556  A disgraced FBI agent with a drinking problem ...   2002-01-04
# 8557  Ángela Vidal, the young television reporter wh...   2014-10-31
# 8558  Two mismatched cops team up to investigate the...   2012-12-15
# 8559  The only U.S. Marshal assigned to Antarctica, ...   2009-09-09
#
#       popularity  vote_average  vote_count
# 0        161.431         8.705       26162
# 1        138.984         8.700       19834
# 2        196.548         8.600       11971
# 3         99.102         8.568       15377
# 4         84.730         8.542        8247
# ...          ...           ...         ...
# 8555      11.033         5.600         315
# 8556      26.122         5.600         616
# 8557      59.133         5.600        1090
# 8558      16.628         5.569         649
# 8559      18.595         5.569         721
#
# [8560 rows x 7 columns]

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
